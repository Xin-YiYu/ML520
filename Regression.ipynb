# %% [markdown]
# CRIM：人均犯罪率
#
# ZN：25,000平方英尺以上民用土地的比例
#
# INDUS：城镇非零售业商用土地比例
#
# CHAS：是否邻近查尔斯河，1是邻近，0是不邻近
#
# NOX：一氧化氮浓度（千万分之一）
#
# RM：住宅的平均房间数
#
# AGE：自住且建于1940年前的房屋比例
#
# DIS：到5个波士顿就业中心的加权距离
#
# RAD：到高速公路的便捷度指数
#
# TAX：每万元的房产税率
#
# PTRATIO：城镇学生教师比例
#
# B： 1000(Bk − 0.63)2 其中Bk是城镇中黑人比例
#
# LSTAT：低收入人群比例
#
# MEDV：自住房中位数价格，单位是千元

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()
df = pd.DataFrame(boston["data"], columns = boston["feature_names"])
df["ans"] = boston ["target"]
# df.to_csv ("boston.csv", encoding = "utf-8", index = False )
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT   ans
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# 把資料(隨機)要分成兩組 - 一組訓練(90%) 一組考試(10%)
from sklearn.model_selection import train_test_split
# [90 %題目, 10 %題目, 90% 答案, 10 %答案]
x_train, x_test, y_train, y_test = train_test_split(boston["data"], 
                                                    boston["target"], 
                                                    test_size = 0.1)

# %%
# 準備模型
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth = 4)

# %%
# 訓練(fit)模型： 考古題
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
# 秀出公式長啥樣子
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(reg, 
                            feature_names=boston["feature_names"],
                            filled=True)
graphviz.Source(g)

# %%
# 驗證模型： 考試
from sklearn.metrics import r2_score
pre = reg.predict(x_test) 
print("預測：", list(pre))
print("正確：", list(y_test))
print("正確率：", r2_score(y_test, pre))
# Out:
# 預測： [27.227999999999998, 21.472352941176467, 32.8972972972973, 16.230985915492955, 21.472352941176467, 21.472352941176467, 27.227999999999998, 20.069565217391307, 10.932142857142855, 21.472352941176467, 10.932142857142855, 10.932142857142855, 21.472352941176467, 16.230985915492955, 21.472352941176467, 21.472352941176467, 21.472352941176467, 10.932142857142855, 21.472352941176467, 21.472352941176467, 21.472352941176467, 32.8972972972973, 21.472352941176467, 32.8972972972973, 27.227999999999998, 21.472352941176467, 10.932142857142855, 21.472352941176467, 10.932142857142855, 21.472352941176467, 21.472352941176467, 21.472352941176467, 16.230985915492955, 46.98, 21.472352941176467, 21.472352941176467, 27.227999999999998, 27.227999999999998, 21.472352941176467, 16.230985915492955, 50.0, 16.230985915492955, 21.472352941176467, 16.230985915492955, 32.8972972972973, 50.0, 21.472352941176467, 21.472352941176467, 21.472352941176467, 16.863636363636363, 21.472352941176467]
# 正確： [32.0, 20.4, 31.7, 13.8, 21.7, 24.4, 27.5, 18.9, 14.1, 19.4, 13.8, 17.1, 22.6, 17.5, 17.4, 22.2, 20.1, 10.5, 21.7, 25.0, 23.8, 33.8, 25.0, 36.4, 26.5, 21.0, 11.9, 24.3, 7.2, 21.2, 22.9, 19.9, 18.7, 35.2, 17.5, 36.2, 32.0, 29.1, 22.5, 18.8, 50.0, 16.1, 23.3, 13.1, 23.6, 27.9, 19.3, 29.6, 22.8, 14.1, 23.3]
# 正確率： 0.5705372194416981
